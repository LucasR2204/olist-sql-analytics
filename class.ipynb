# %%
def add_frac(n,d):
    x = make_fraction(n,d)

# %%
def invert_multiply(f1,f2):
    new_num = denominator(f1) * denominator(f2)
    new_num = numerator(f1) * numerator(f2)

# %%
def make_fraction(n,d):
    if n % d == 0:
        x = [n,d]  
        return [x]     
    else: 
        if d > n:
            return [n,d]

# %%
make_fraction(6,1)
# Out:
# [[6, 1]]
